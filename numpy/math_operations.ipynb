# %% [markdown]
# # Math Operations

# %% [markdown]
# ## Importing library and inicialize ndarray

# %%
import numpy as np

a = np.array([12, 54, 54, 45])
b = np.array([78, 56, 94, 21])

# %%
print("Sum: ", a + b)
print("Difference: ", a - b)
print("Product: ", a * b)
print("Quotient: ", a / b)
# Out:
# Sum:  [ 90 110 148  66]
# Difference:  [-66  -2 -40  24]
# Product:  [ 936 3024 5076  945]
# Quotient:  [0.15384615 0.96428571 0.57446809 2.14285714]
